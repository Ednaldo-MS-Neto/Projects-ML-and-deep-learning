# %% [markdown]
# # Projeto 13: Compressão de imagens

# %% [markdown]
# # Etapa 1: Importação das biblitoecas

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from tensorflow.keras import layers
import pandas as pd
import seaborn as sns
import pickle
import zipfile
import random
tf.__version__
# Out:
# '2.8.2'

# %% [markdown]
# # Etapa 2: Carregamento da base de dados

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/My Drive/Deep learning/traffic-signs-data.zip"
zip_object = zipfile.ZipFile(file=path, mode="r")
zip_object.extractall("./")
zip_object.close()

# %%
with open("traffic-signs-data/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("traffic-signs-data/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("traffic-signs-data/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
plt.imshow(X_train[1105])

# %% [markdown]
# # Etapa 3: Visualização dos dados

# %%
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
X_test.shape
# Out:
# (12630, 32, 32, 3)

# %%
i = random.randint(1,34000) 
plt.imshow( X_train[i] , cmap = 'gray')

# %%
label = y_train[i]
label
# Out:
# 25

# %%
W_grid = 15
L_grid = 15

fig, axes = plt.subplots(L_grid, W_grid, figsize = (17,17))

axes = axes.ravel()
n_training = len(X_train)

for i in np.arange(0, W_grid * L_grid):
    index = np.random.randint(0, n_training)
    axes[i].imshow( X_train[index] )
    axes[i].set_title(y_train[index], fontsize = 8)
    axes[i].axis('off')
plt.subplots_adjust(hspace=0.4)

# %% [markdown]
# # Etapa 4: Pré-processamento

# %%
X_train = X_train / 255
X_test = X_test / 255

# %% [markdown]
# # Etapa 5: Criação e treinamento do autoencoder

# %%
autoencoder = tf.keras.models.Sequential()

# Encoder
autoencoder.add(tf.keras.layers.Conv2D(64, (3,3), strides=1, padding="same", input_shape=(32, 32, 3)))
autoencoder.add(tf.keras.layers.BatchNormalization())
autoencoder.add(tf.keras.layers.Activation('relu'))
autoencoder.add(tf.keras.layers.AveragePooling2D((2,2), padding="same"))

autoencoder.add(tf.keras.layers.Conv2D(32, (3,3), strides=1, padding="same"))
autoencoder.add(tf.keras.layers.BatchNormalization())
autoencoder.add(tf.keras.layers.Activation('relu'))
autoencoder.add(tf.keras.layers.AveragePooling2D((2,2), padding="same"))

autoencoder.add(tf.keras.layers.Conv2D(16, (3,3), strides=1, padding="same"))
autoencoder.add(tf.keras.layers.BatchNormalization())
autoencoder.add(tf.keras.layers.Activation('relu'))

# Encoded image (Code Layer)
autoencoder.add(tf.keras.layers.AveragePooling2D((2,2), padding="same")) 

# Decoder
autoencoder.add(tf.keras.layers.Conv2D(16, (3,3), strides=1, padding="same"))
autoencoder.add(tf.keras.layers.BatchNormalization())
autoencoder.add(tf.keras.layers.Activation('relu'))
autoencoder.add(tf.keras.layers.UpSampling2D((2, 2)))

autoencoder.add(tf.keras.layers.Conv2D(32, (3,3), strides=1, padding="same"))
autoencoder.add(tf.keras.layers.BatchNormalization())
autoencoder.add(tf.keras.layers.Activation('relu'))
autoencoder.add(tf.keras.layers.UpSampling2D((2, 2)))

autoencoder.add(tf.keras.layers.Conv2D(64, (3,3), strides=1, padding="same"))
autoencoder.add(tf.keras.layers.BatchNormalization())
autoencoder.add(tf.keras.layers.Activation('relu'))
autoencoder.add(tf.keras.layers.UpSampling2D((2, 2)))

#sigmoid pois esta´normalizado entre 0 e 1
autoencoder.add(tf.keras.layers.Conv2D(3, (3,3), strides=1, activation='sigmoid', padding="same"))

# %%
autoencoder.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(lr=0.01))
autoencoder.summary();
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  batch_normalization (BatchN  (None, 32, 32, 64)       256
#  ormalization)
#
#  activation (Activation)     (None, 32, 32, 64)        0
#
#  average_pooling2d (AverageP  (None, 16, 16, 64)       0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 32)        18464
#
#  batch_normalization_1 (Batc  (None, 16, 16, 32)       128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 16, 16, 32)        0
#
#  average_pooling2d_1 (Averag  (None, 8, 8, 32)         0
#  ePooling2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 16)          4624
#
#  batch_normalization_2 (Batc  (None, 8, 8, 16)         64
#  hNormalization)
#
#  activation_2 (Activation)   (None, 8, 8, 16)          0
#
#  average_pooling2d_2 (Averag  (None, 4, 4, 16)         0
#  ePooling2D)
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 16)          2320
#
#  batch_normalization_3 (Batc  (None, 4, 4, 16)         64
#  hNormalization)
#
#  activation_3 (Activation)   (None, 4, 4, 16)          0
#
#  up_sampling2d (UpSampling2D  (None, 8, 8, 16)         0
#  )
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 32)          4640
#
#  batch_normalization_4 (Batc  (None, 8, 8, 32)         128
#  hNormalization)
#
#  activation_4 (Activation)   (None, 8, 8, 32)          0
#
#  up_sampling2d_1 (UpSampling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_5 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  activation_5 (Activation)   (None, 16, 16, 64)        0
#
#  up_sampling2d_2 (UpSampling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 3)         1731
#
# =================================================================
# Total params: 52,963
# Trainable params: 52,515
# Non-trainable params: 448
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
autoencoder.fit(X_train,          
          X_train, #passando X_train como resposta por ser um encoder
          epochs=20, 
          batch_size=200, 
          validation_data=(X_test, X_test))
# Out:
# Epoch 1/20
# 174/174 [==============================] - 18s 35ms/step - loss: 0.5066 - val_loss: 0.5153
# Epoch 2/20
# 174/174 [==============================] - 4s 26ms/step - loss: 0.4875 - val_loss: 0.4947
# Epoch 3/20
# 174/174 [==============================] - 4s 26ms/step - loss: 0.4827 - val_loss: 0.4838
# Epoch 4/20
# 174/174 [==============================] - 5s 26ms/step - loss: 0.4800 - val_loss: 0.4823
# Epoch 5/20
# 174/174 [==============================] - 4s 25ms/step - loss: 0.4784 - val_loss: 0.4778
# Epoch 6/20
# 174/174 [==============================] - 5s 26ms/step - loss: 0.4763 - val_loss: 0.4755
# Epoch 7/20
# 174/174 [==============================] - 4s 26ms/step - loss: 0.4750 - val_loss: 0.4772
# Epoch 8/20
# 174/174 [==============================] - 4s 26ms/step - loss: 0.4733 - val_loss: 0.4778
# Epoch 9/20
# 174/174 [==============================] - 5s 27ms/step - loss: 0.4722 - val_loss: 0.4765
# Epoch 10/20
# 174/174 [==============================] - 5s 26ms/step - loss: 0.4714 - val_loss: 0.4827
# Epoch 11/20
# 174/174 [==============================] - 4s 26ms/step - loss: 0.4706 - val_loss: 0.4712
# Epoch 12/20
# 174/174 [==============================] - 4s 26ms/step - loss: 0.4698 - val_loss: 0.4671
# Epoch 13/20
# 174/174 [==============================] - 4s 26ms/step - loss: 0.4694 - val_loss: 0.4673
# Epoch 14/20
# 174/174 [==============================] - 5s 29ms/step - loss: 0.4690 - val_loss: 0.4746
# Epoch 15/20
# 174/174 [==============================] - 6s 34ms/step - loss: 0.4685 - val_loss: 0.4700
# Epoch 16/20
# 174/174 [==============================] - 5s 29ms/step - loss: 0.4683 - val_loss: 0.4878
# Epoch 17/20
# 174/174 [==============================] - 5s 29ms/step - loss: 0.4679 - val_loss: 0.4693
# Epoch 18/20
# 174/174 [==============================] - 5s 26ms/step - loss: 0.4675 - val_loss: 0.4679
# Epoch 19/20
# 174/174 [==============================] - 5s 26ms/step - loss: 0.4671 - val_loss: 0.4675
# Epoch 20/20
# 174/174 [==============================] - 5s 26ms/step - loss: 0.4672 - val_loss: 0.4644

# %% [markdown]
# # Etapa 6: Avaliação do modelo

# %%
predicted = autoencoder.predict(X_test[:10].reshape(-1, 32, 32, 3))

# %%
predicted.shape
# Out:
# (10, 32, 32, 3)

# %%
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(20,4))
for images, row in zip([X_test[:10], predicted], axes):
    for img, ax in zip(images, row):
        ax.imshow(img.reshape((32, 32, 3)))
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
